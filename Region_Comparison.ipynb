# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df1 = pd.read_excel('popn_demographics.xlsx')

# %%
new_column_names = [
    "Age Group",
    "2000", "2001", "2002", "2003", "2004", "2005", "2006", "2007", "2008", "2009",
    "2010", "2011", "2012", "2013", "2014", "2015", "2016", "2017", "2018", "2019",
    "2020", "2021", "2022", "2023", "2024", "2025", "2026", "2027", "2028", "2029",
    "2030", "2031", "2032", "2033", "2034", "2035", "2036", "2037", "2038", "2039", "2040"
]

# %%
# Rename the columns
df1.columns = new_column_names

# %%
# Drop the first row
df1 = df1[1:]

# %%
df1.head()
# Out:
#                               Age Group    2000    2001    2002    2003  \
# 1   Population, 100+ Years in million #   1.379   1.453   1.528   1.608
# 2  Population, 95-99 Years in million #   6.904   7.234   7.579   7.922
# 3  Population, 90-94 Years in million #  21.160  21.390  21.460  21.540
# 4               Population in billion #   5.937   6.014   6.090   6.165
# 5    Population, 55+ Years in billion #   1.386   1.397   1.414   1.434
#
#      2004    2005    2006    2007    2008  ...    2031    2032    2033  \
# 1   1.703   1.809   1.918   2.038   2.155  ...   6.710   7.036   7.361
# 2   8.277   8.555   8.704   8.801   8.915  ...  25.430  26.270  27.070
# 3  21.980  23.020  24.530  26.140  27.860  ...  59.820  63.360  67.590
# 4   6.241   6.317   6.394   6.471   6.550  ...   8.178   8.236   8.293
# 5   1.457   1.483   1.512   1.543   1.577  ...   2.452   2.489   2.526
#
#      2034    2035    2036    2037    2038    2039    2040
# ...

# %%
# df2.head()

# %%
# Transpose the DataFrames to have years as columns
age_group_df = df1.transpose()

# Set the first row as column headers
age_group_df.columns = age_group_df.iloc[0]

# Drop the first row (since it's now used as column headers)
age_group_df = age_group_df[1:]

# Convert the index (years) to datetime objects for better plotting
age_group_df.index = pd.to_datetime(age_group_df.index)

# Plotting
plt.figure(figsize=(12, 6))
plt.plot(age_group_df.index, age_group_df['Population, 100+ Years in million #'], label='100+ Years')
plt.plot(age_group_df.index, age_group_df['Population, 95-99 Years in million #'], label='95-99 Years')
plt.plot(age_group_df.index, age_group_df['Population, 90-94 Years in million #'], label='90-94 Years')
# plt.plot(age_group_df.index, age_group_df['Population in billion #'], label='Popn in billion')
plt.plot(age_group_df.index, age_group_df['Population, 85-89 Years in million #'], label='85-89 Years')
plt.plot(age_group_df.index, age_group_df['Population, 80-84 Years in million #'], label='80-84 Years')
plt.plot(age_group_df.index, age_group_df['Population, 75-79 Years in million #'], label='75-79 Years')
plt.plot(age_group_df.index, age_group_df['Population, 70-74 Years in million #'], label='70-74 Years')
plt.plot(age_group_df.index, age_group_df['Population, 65-69 Years in million #'], label='65-69 Years')
plt.plot(age_group_df.index, age_group_df['Population, 60-64 Years in billion #'], label='60-64 Years')
plt.plot(age_group_df.index, age_group_df['Population, 55-59 Years in million #'], label='55-59 Years')
plt.plot(age_group_df.index, age_group_df['Population, 55+ Years in billion #'], label='55+')
plt.plot(age_group_df.index, age_group_df['Population, 45-54 Years in billion #'], label='45-54 Years')

plt.xlabel('Year')
plt.ylabel('Population')
plt.title('Age Group Population Trends')
plt.legend()
plt.grid(True)
plt.show()

# %%
# import pandas as pd

data = {
    "Region": ["Worldwide", "ASEAN", "Baltics", "BeNeLux", "BRICS", "CIS", "D-A-CH", "EAEU", "EU27", "G7", "G20", "GCC", "NAFTA", "Nordics"],
    "2012": [0.16, 0.27, 0.66, 0.76, 0.06, 0.39, 0.80, 0.48, 0.49, 0.44, 0.17, 0.64, 0.29, 0.30],
    "2013": [0.16, 0.29, 0.62, 0.73, 0.06, 0.40, 0.78, 0.48, 0.48, 0.44, 0.17, 0.68, 0.29, 0.31],
    "2014": [0.17, 0.30, 0.59, 0.74, 0.06, 0.40, 0.77, 0.49, 0.47, 0.44, 0.17, 0.72, 0.28, 0.31],
    "2015": [0.17, 0.32, 0.57, 0.82, 0.06, 0.41, 0.78, 0.50, 0.47, 0.44, 0.17, 0.75, 0.28, 0.30],
    "2016": [0.17, 0.34, 0.55, 0.93, 0.07, 0.42, 0.79, 0.51, 0.47, 0.44, 0.18, 0.77, 0.27, 0.30],
    "2017": [0.18, 0.35, 0.54, 1.05, 0.07, 0.43, 0.80, 0.52, 0.47, 0.45, 0.18, 0.78, 0.27, 0.29],
    "2018": [0.18, 0.36, 0.53, 1.17, 0.07, 0.45, 0.84, 0.55, 0.49, 0.46, 0.18, 0.80, 0.28, 0.28],
    "2019": [0.18, 0.36, 0.51, 1.17, 0.07, 0.46, 0.83, 0.56, 0.49, 0.46, 0.19, 0.81, 0.28, 0.29],
    "2020": [0.18, 0.36, 0.46, 1.16, 0.07, 0.43, 0.81, 0.53, 0.48, 0.46, 0.19, 0.83, 0.28, 0.29],
    "2021": [0.18, 0.37, 0.46, 1.10, 0.07, 0.46, 0.82, 0.56, 0.48, 0.46, 0.18, 0.84, 0.29, 0.30],
    "2022": [0.17, 0.37, 0.40, 0.94, 0.06, 0.34, 0.73, 0.41, 0.42, 0.43, 0.18, 0.83, 0.28, 0.26],
    "2023": [0.18, 0.39, 0.44, 0.98, 0.07, 0.40, 0.78, 0.48, 0.45, 0.46, 0.19, 0.86, 0.29, 0.28],
    "2024": [0.18, 0.39, 0.43, 0.96, 0.07, 0.40, 0.78, 0.48, 0.45, 0.46, 0.19, 0.88, 0.29, 0.29]
}

df = pd.DataFrame(data)
# print(df)

# %% [markdown]
# ### To identify target markets for selling soluble coffee, we can use data visualization techniques to analyze the average volume per capita consumption over the years for different regions.

# %% [markdown]
#  #### We'll focus on regions with increasing consumption trends to identify potential target markets.

# %%
import matplotlib.pyplot as plt

# Set the style of the plots
plt.style.use('seaborn')

# Extract data for plotting
years = df.columns[1:]
regions = df['Region']
consumption_data = df.drop('Region', axis=1)

# Plotting
plt.figure(figsize=(12, 8))

for index, region in enumerate(regions):
    plt.plot(years, consumption_data.iloc[index], label=region, marker='o')

plt.title('Average Volume per Capita Consumption of Soluble Coffee by Region')
plt.xlabel('Year')
plt.ylabel('Average Volume per Capita (kg)')
plt.xticks(rotation=45)
plt.legend(bbox_to_anchor=(1, 1))
plt.grid(True)
plt.tight_layout()

plt.show()
# Out:
# /tmp/ipykernel_5347/609735794.py:4: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use('seaborn')

# %% [markdown]
# #### After analyzing the plot, you can focus on regions where the consumption trend is consistently increasing or where there are significant spikes in consumption. These regions might be potential target markets for selling soluble coffee.
#
# #### Additionally, you can calculate the growth rate for each region and identify the regions with the highest growth rates over a specific period. This can provide further insights into which regions are experiencing the most rapid increase in consumption.
#
# #### Other factors such as market size, competition, economic conditions, and cultural preferences also play a role in identifying target markets. Data visualization is a helpful tool, but it should be combined with a comprehensive market analysis for effective decision-making.

# %% [markdown]
# #### With the visualization above, Regions of CIS show an upward trend and a good recovery from covid. the Nordics, EAEU, ASEAN Also show an upward trend for home coffee consuption. These are markets we should pay close attention too and get in business with.

# %% [markdown]
# ### Data on Revenue percapita

# %%
# import pandas as pd

data = {
    "Region": ["Worldwide", "ASEAN", "Baltics", "BeNeLux", "BRICS", "CIS", "D-A-CH", "EAEU", "EU27", "G7", "G20", "GCC", "NAFTA", "Nordics"],
    "2012": [3.38, 3.69, 11.83, 13.41, 0.99, 6.69, 19.58, 8.42, 10.33, 12.82, 3.96, 13.56, 5.93, 11.52],
    "2013": [3.42, 4.03, 11.83, 13.31, 1.09, 7.39, 19.74, 9.32, 10.56, 12.04, 3.95, 14.70, 5.99, 11.85],
    "2014": [3.38, 4.14, 11.53, 13.38, 1.09, 6.66, 19.58, 8.38, 10.51, 11.76, 3.90, 15.90, 5.78, 11.36],
    "2015": [3.08, 4.28, 9.58, 12.30, 0.94, 4.84, 16.56, 6.08, 8.79, 10.62, 3.49, 15.97, 5.32, 9.29],
    "2016": [3.17, 4.52, 9.61, 14.24, 0.98, 4.85, 16.76, 6.11, 8.88, 11.26, 3.62, 16.51, 5.09, 9.15],
    "2017": [3.31, 4.72, 9.95, 17.15, 1.15, 6.05, 17.33, 7.69, 9.41, 11.20, 3.80, 17.00, 5.22, 9.49],
    "2018": [3.46, 4.91, 10.67, 21.51, 1.18, 6.33, 18.87, 8.07, 10.23, 11.92, 4.00, 18.07, 5.47, 9.91],
    "2019": [3.48, 5.25, 10.01, 20.72, 1.21, 6.71, 17.83, 8.58, 9.76, 12.05, 4.02, 18.88, 5.66, 9.52],
    "2020": [3.45, 5.47, 9.30, 20.96, 1.12, 6.05, 17.66, 7.74, 9.74, 12.38, 4.01, 19.38, 5.55, 9.69],
    "2021": [3.68, 5.93, 10.18, 21.06, 1.24, 7.06, 19.19, 9.07, 10.43, 13.10, 4.30, 20.07, 5.85, 10.68],
    "2022": [3.55, 6.08, 9.26, 18.48, 1.15, 5.29, 17.50, 6.78, 9.42, 12.75, 4.14, 20.14, 5.78, 9.67],
    "2023": [3.82, 6.48, 10.24, 19.23, 1.30, 6.37, 18.89, 8.19, 10.08, 13.80, 4.48, 21.12, 6.06, 10.51],
    "2024": [3.90, 6.59, 10.24, 18.95, 1.35, 6.48, 19.10, 8.35, 10.13, 14.21, 4.60, 21.74, 6.18, 10.72],
    "2025": [3.98, 6.72, 10.26, 18.66, 1.40, 6.58, 19.26, 8.48, 10.16, 14.59, 4.72, 22.34, 6.29, 10.91]
}

df = pd.DataFrame(data)

# %% [markdown]
# #### This plot can help you visually identify regions with strong growth trends in GDP per capita.
#
# #### Remember that GDP per capita growth is an important indicator of economic development, but it's also influenced by various factors including inflation, population growth, and economic policies. Therefore, make sure to consider these aspects when interpreting the visualizations and drawing conclusions about potential target markets.

# %%
import matplotlib.pyplot as plt

# Set the style of the plots
plt.style.use('seaborn')

# Extract data for plotting
years = df.columns[1:]
regions = df['Region']
gdp_data = df.drop('Region', axis=1)

# Plotting
plt.figure(figsize=(12, 8))

for index, region in enumerate(regions):
    plt.plot(years, gdp_data.iloc[index], label=region, marker='o')

plt.title('GDP per Capita Growth by Region')
plt.xlabel('Year')
plt.ylabel('GDP per Capita')
plt.xticks(rotation=45)
plt.legend(bbox_to_anchor=(1, 1))
plt.grid(True)
plt.tight_layout()

plt.show()
# Out:
# /tmp/ipykernel_5347/3999162242.py:4: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use('seaborn')

# %% [markdown]
# #### This plot can help you visually identify regions with strong growth trends in GDP per capita.
#
# #### Remember that GDP per capita growth is an important indicator of economic development, but it's also influenced by various factors including inflation, population growth, and economic policies. Therefore, make sure to consider these aspects when interpreting the visualizations and drawing conclusions about potential target markets.
